# %%
import os
from PIL import Image
savepath = r'D:\images'
directory = r'C:\Users\PRADEEP\Downloads\www_google_com\New folder'
i = 0
for filename in os.listdir(directory):
    print(filename)
    im = Image.open(f'{directory}/{filename}')
    i = i+1
    im.save(f'{savepath}/{i}.png')
# Out:
# 11042_2020_10126_Fig2_HTML.png
# 0
# 11042_2020_10126_Fig3_HTML.png
# 1
# 11042_2020_10126_Fig6_HTML.png
# 2
# 1561630075-without_helmet.jpg
# 3
# 16-08-2020kanakapurakarnatakaindia-triple-riding-with-a-bike-in-india-2CC2W28.jpg
# 4
# 16-08-2020kanakapurakarnatakaindia-triple-riding-with-a-bike-in-india-2CC2W29.jpg
# 5
# 1b8eff0af2ad9984a398f75bf67ac1c6.jpg
# 6
# 1cf9278e8cd923853711ce83e03c8637.jpg
# 7
# 358875.gif
# 8
# 626455-motorcyclebikeexpress-1383452507.jpg
# 9
# 65764012.jpg
# 10
# 70314574.jpg
# 11
# All-Movie-Fans-Bellamkonda-Sai-Sreenivas-Triple-Riding-On-Hyd-Streets.jpg
# 12
# b2877b9a9732e27d38bc6515b2a46e89.jpg
# 13
# boys-riding-triple-seat-on-bike-pushkar-fair-rajasthan-india-FCTW3X.jpg
# 14
# c66837448d6bde3d1b251ffa40ed30cc.jpg
# 15
# chd4.jpg
# 16
# cops.jpg
# 17
# d48871ee1b46c6e4ea31cf366d170e84.jpg
# 18
# death-on-bike-ride_1468175934.jpeg
# 19
# DHuH26iV0AANcj5.jpg
# 20
# download (1).jfif
# 21
# download (10).jfif
# 22
# download (11).jfif
# 23
# ...
